# %% [markdown]
# # Descriptive Statistics
# ## After cleaning/formatting and normalization

# %%
import pandas as pd
import numpy as np

# %%
df = pd.read_csv("C:/Users/Jay Rao/Desktop/IBM Data analysis with Python/automobiles_fuel_dummies.csv")

# %%
df.head(20)
# Out:
#     Unnamed: 0  symboling  normalized-losses         make fuel-type  \
# 0            0          3              99.54  alfa-romero       gas
# 1            1          3              99.54  alfa-romero       gas
# 2            2          1              99.54  alfa-romero       gas
# 3            3          2             164.00         audi       gas
# 4            4          2             164.00         audi       gas
# 5            5          2              99.54         audi       gas
# 6            6          1             158.00         audi       gas
# 7            7          1              99.54         audi       gas
# 8            8          1             158.00         audi       gas
# 9            9          2             192.00          bmw       gas
# 10          10          0             192.00          bmw       gas
# 11          11          0             188.00          bmw       gas
# 12          12          0             188.00          bmw       gas
# 13          13          1              99.54          bmw       gas
# 14          14          0              99.54          bmw       gas
# 15          15          0              99.54          bmw       gas
# 16          16          0              99.54          bmw       gas
# 17          17          2             121.00    chevrolet       gas
# 18          18          1              98.00    chevrolet       gas
# 19          19          0              81.00    chevrolet       gas
#
#    aspiration num-of-doors   body-style drive-wheels engine-location  ...  \
# 0         std          two  convertible          rwd           front  ...
# 1         std          two  convertible          rwd           front  ...
# 2         std          two    hatchback          rwd           front  ...
# 3         std         four        sedan          fwd           front  ...
# 4         std         four        sedan          4wd           front  ...
# 5         std          two        sedan          fwd           front  ...
# 6         std         four        sedan          fwd           front  ...
# 7         std         four        wagon          fwd           front  ...
# 8       turbo         four        sedan          fwd           front  ...
# 9         std          two        sedan          rwd           front  ...
# 10        std         four        sedan          rwd           front  ...
# 11        std          two        sedan          rwd           front  ...
# 12        std         four        sedan          rwd           front  ...
# 13        std         four        sedan          rwd           front  ...
# 14        std         four        sedan          rwd           front  ...
# 15        std          two        sedan          rwd           front  ...
# 16        std         four        sedan          rwd           front  ...
# 17        std          two    hatchback          fwd           front  ...
# 18        std          two    hatchback          fwd           front  ...
# 19        std         four        sedan          fwd           front  ...
#
#     stroke  compression-ratio  horsepower  peak-rpm  city-mpg highway-mpg  \
# 0     2.68                9.0         111      5000        21          27
# 1     2.68                9.0         111      5000        21          27
# 2     3.47                9.0         154      5000        19          26
# 3     3.40               10.0         102      5500        24          30
# 4     3.40                8.0         115      5500        18          22
# 5     3.40                8.5         110      5500        19          25
# 6     3.40                8.5         110      5500        19          25
# 7     3.40                8.5         110      5500        19          25
# 8     3.40                8.3         140      5500        17          20
# 9     2.80                8.8         101      5800        23          29
# 10    2.80                8.8         101      5800        23          29
# 11    3.19                9.0         121      4250        21          28
# 12    3.19                9.0         121      4250        21          28
# 13    3.19                9.0         121      4250        20          25
# 14    3.39                8.0         182      5400        16          22
# 15    3.39                8.0         182      5400        16          22
# 16    3.39                8.0         182      5400        15          20
# 17    3.03                9.5          48      5100        47          53
# 18    3.11                9.6          70      5400        38          43
# 19    3.11                9.6          70      5400        38          43
#
#     price  price-binned diesel gas
# 0   13495           low      0   1
# 1   16500           low      0   1
# 2   16500           low      0   1
# 3   13950           low      0   1
# 4   17450           low      0   1
# 5   15250           low      0   1
# 6   17710           low      0   1
# 7   18920        medium      0   1
# 8   23875        medium      0   1
# 9   16430           low      0   1
# 10  16925           low      0   1
# 11  20970        medium      0   1
# 12  21105        medium      0   1
# 13  24565        medium      0   1
# 14  30760        medium      0   1
# 15  41315          high      0   1
# 16  36880          high      0   1
# 17   5151           low      0   1
# 18   6295           low      0   1
# 19   6575           low      0   1
#
# [20 rows x 30 columns]

# %%
#drop the first unecessary column

df = df.drop(df.columns[[0]],axis = 1)

# %%
df.head(20)
# Out:
#     symboling  normalized-losses         make fuel-type aspiration  \
# 0           3              99.54  alfa-romero       gas        std
# 1           3              99.54  alfa-romero       gas        std
# 2           1              99.54  alfa-romero       gas        std
# 3           2             164.00         audi       gas        std
# 4           2             164.00         audi       gas        std
# 5           2              99.54         audi       gas        std
# 6           1             158.00         audi       gas        std
# 7           1              99.54         audi       gas        std
# 8           1             158.00         audi       gas      turbo
# 9           2             192.00          bmw       gas        std
# 10          0             192.00          bmw       gas        std
# 11          0             188.00          bmw       gas        std
# 12          0             188.00          bmw       gas        std
# 13          1              99.54          bmw       gas        std
# 14          0              99.54          bmw       gas        std
# 15          0              99.54          bmw       gas        std
# 16          0              99.54          bmw       gas        std
# 17          2             121.00    chevrolet       gas        std
# 18          1              98.00    chevrolet       gas        std
# 19          0              81.00    chevrolet       gas        std
#
#    num-of-doors   body-style drive-wheels engine-location  wheel-base  ...  \
# 0           two  convertible          rwd           front        88.6  ...
# 1           two  convertible          rwd           front        88.6  ...
# 2           two    hatchback          rwd           front        94.5  ...
# 3          four        sedan          fwd           front        99.8  ...
# 4          four        sedan          4wd           front        99.4  ...
# 5           two        sedan          fwd           front        99.8  ...
# 6          four        sedan          fwd           front       105.8  ...
# 7          four        wagon          fwd           front       105.8  ...
# 8          four        sedan          fwd           front       105.8  ...
# 9           two        sedan          rwd           front       101.2  ...
# 10         four        sedan          rwd           front       101.2  ...
# 11          two        sedan          rwd           front       101.2  ...
# 12         four        sedan          rwd           front       101.2  ...
# 13         four        sedan          rwd           front       103.5  ...
# 14         four        sedan          rwd           front       103.5  ...
# 15          two        sedan          rwd           front       103.5  ...
# 16         four        sedan          rwd           front       110.0  ...
# 17          two    hatchback          fwd           front        88.4  ...
# 18          two    hatchback          fwd           front        94.5  ...
# 19         four        sedan          fwd           front        94.5  ...
#
#     stroke  compression-ratio  horsepower  peak-rpm city-mpg highway-mpg  \
# 0     2.68                9.0         111      5000       21          27
# 1     2.68                9.0         111      5000       21          27
# 2     3.47                9.0         154      5000       19          26
# 3     3.40               10.0         102      5500       24          30
# 4     3.40                8.0         115      5500       18          22
# 5     3.40                8.5         110      5500       19          25
# 6     3.40                8.5         110      5500       19          25
# 7     3.40                8.5         110      5500       19          25
# 8     3.40                8.3         140      5500       17          20
# 9     2.80                8.8         101      5800       23          29
# 10    2.80                8.8         101      5800       23          29
# 11    3.19                9.0         121      4250       21          28
# 12    3.19                9.0         121      4250       21          28
# 13    3.19                9.0         121      4250       20          25
# 14    3.39                8.0         182      5400       16          22
# 15    3.39                8.0         182      5400       16          22
# 16    3.39                8.0         182      5400       15          20
# 17    3.03                9.5          48      5100       47          53
# 18    3.11                9.6          70      5400       38          43
# 19    3.11                9.6          70      5400       38          43
#
#     price price-binned diesel gas
# 0   13495          low      0   1
# 1   16500          low      0   1
# 2   16500          low      0   1
# 3   13950          low      0   1
# 4   17450          low      0   1
# 5   15250          low      0   1
# 6   17710          low      0   1
# 7   18920       medium      0   1
# 8   23875       medium      0   1
# 9   16430          low      0   1
# 10  16925          low      0   1
# 11  20970       medium      0   1
# 12  21105       medium      0   1
# 13  24565       medium      0   1
# 14  30760       medium      0   1
# 15  41315         high      0   1
# 16  36880         high      0   1
# 17   5151          low      0   1
# 18   6295          low      0   1
# 19   6575          low      0   1
#
# [20 rows x 29 columns]
