# %% [markdown]
# # Normalization of the datasets is very crucial for further statistical analysis
#
# ## Best practice is to use CIT to get a sample distribution of means
#
#
# ## However there are mainly three techniques to normalize a column
#
#
# ### 1. value/max value of that column
# ### 2. value - min(values of that column)/max-min
# ### 3. mean(column)/column.std() -- Z score

# %%
#let us import a dataset and normalize the column

import pandas as pd
import numpy as np
import seaborn as sb

# %%
df = pd.read_csv("../automobile_formatted.csv")

# %%
df.head(10)
# Out:
#    Unnamed: 0  symboling  normalized-losses         make fuel-type aspiration  \
# 0           0          3              99.54  alfa-romero       gas        std
# 1           1          3              99.54  alfa-romero       gas        std
# 2           2          1              99.54  alfa-romero       gas        std
# 3           3          2             164.00         audi       gas        std
# 4           4          2             164.00         audi       gas        std
# 5           5          2              99.54         audi       gas        std
# 6           6          1             158.00         audi       gas        std
# 7           7          1              99.54         audi       gas        std
# 8           8          1             158.00         audi       gas      turbo
# 9           9          2             192.00          bmw       gas        std
#
#   num-of-doors   body-style drive-wheels engine-location  ...  engine-size  \
# 0          two  convertible          rwd           front  ...          130
# 1          two  convertible          rwd           front  ...          130
# 2          two    hatchback          rwd           front  ...          152
# 3         four        sedan          fwd           front  ...          109
# 4         four        sedan          4wd           front  ...          136
# 5          two        sedan          fwd           front  ...          136
# 6         four        sedan          fwd           front  ...          136
# 7         four        wagon          fwd           front  ...          136
# 8         four        sedan          fwd           front  ...          131
# 9          two        sedan          rwd           front  ...          108
#
#    fuel-system  bore  stroke  compression-ratio horsepower peak-rpm  city-mpg  \
# 0         mpfi  3.47    2.68                9.0        111     5000        21
# 1         mpfi  3.47    2.68                9.0        111     5000        21
# 2         mpfi  2.68    3.47                9.0        154     5000        19
# 3         mpfi  3.19    3.40               10.0        102     5500        24
# 4         mpfi  3.19    3.40                8.0        115     5500        18
# 5         mpfi  3.19    3.40                8.5        110     5500        19
# 6         mpfi  3.19    3.40                8.5        110     5500        19
# 7         mpfi  3.19    3.40                8.5        110     5500        19
# 8         mpfi  3.13    3.40                8.3        140     5500        17
# 9         mpfi  3.50    2.80                8.8        101     5800        23
#
#   highway-mpg  price
# 0          27  13495
# 1          27  16500
# 2          26  16500
# 3          30  13950
# 4          22  17450
# 5          25  15250
# 6          25  17710
# 7          25  18920
# 8          20  23875
# 9          29  16430
#
# [10 rows x 27 columns]

# %% [markdown]
# ### Before Normalizing the price

# %%
sb.distplot(df[['price']],hist=True)

# %% [markdown]
# ### Before Normalizing the normalized-losses

# %%
sb.distplot(df[['normalized-losses']],hist=True)

# %% [markdown]
# # Let us normalize the prices

# %%
df["price"] = df["price"]/df["price"].max()

# %%
df.head(10)
# Out:
#    Unnamed: 0  symboling  normalized-losses         make fuel-type aspiration  \
# 0           0          3              99.54  alfa-romero       gas        std
# 1           1          3              99.54  alfa-romero       gas        std
# 2           2          1              99.54  alfa-romero       gas        std
# 3           3          2             164.00         audi       gas        std
# 4           4          2             164.00         audi       gas        std
# 5           5          2              99.54         audi       gas        std
# 6           6          1             158.00         audi       gas        std
# 7           7          1              99.54         audi       gas        std
# 8           8          1             158.00         audi       gas      turbo
# 9           9          2             192.00          bmw       gas        std
#
#   num-of-doors   body-style drive-wheels engine-location  ...  engine-size  \
# 0          two  convertible          rwd           front  ...          130
# 1          two  convertible          rwd           front  ...          130
# 2          two    hatchback          rwd           front  ...          152
# 3         four        sedan          fwd           front  ...          109
# 4         four        sedan          4wd           front  ...          136
# 5          two        sedan          fwd           front  ...          136
# 6         four        sedan          fwd           front  ...          136
# 7         four        wagon          fwd           front  ...          136
# 8         four        sedan          fwd           front  ...          131
# 9          two        sedan          rwd           front  ...          108
#
#    fuel-system  bore  stroke  compression-ratio horsepower peak-rpm  city-mpg  \
# 0         mpfi  3.47    2.68                9.0        111     5000        21
# 1         mpfi  3.47    2.68                9.0        111     5000        21
# 2         mpfi  2.68    3.47                9.0        154     5000        19
# 3         mpfi  3.19    3.40               10.0        102     5500        24
# 4         mpfi  3.19    3.40                8.0        115     5500        18
# 5         mpfi  3.19    3.40                8.5        110     5500        19
# 6         mpfi  3.19    3.40                8.5        110     5500        19
# 7         mpfi  3.19    3.40                8.5        110     5500        19
# 8         mpfi  3.13    3.40                8.3        140     5500        17
# 9         mpfi  3.50    2.80                8.8        101     5800        23
#
#   highway-mpg     price
# 0          27  0.297247
# 1          27  0.363436
# 2          26  0.363436
# 3          30  0.307269
# 4          22  0.384361
# 5          25  0.335903
# 6          25  0.390088
# 7          25  0.416740
# 8          20  0.525881
# 9          29  0.361894
#
# [10 rows x 27 columns]

# %% [markdown]
# ### After normalizing price

# %%
sb.distplot(df[['price']],hist=True)

# %% [markdown]
# # Similarly let us normalize the normalized-losses using min max method

# %%
df["normalized-losses"] = (df["normalized-losses"]-df["normalized-losses"].min())/(df["normalized-losses"].max()-df["normalized-losses"].min())

# %%
df.head(10)
# Out:
#    Unnamed: 0  symboling  normalized-losses         make fuel-type aspiration  \
# 0           0          3           0.180838  alfa-romero       gas        std
# 1           1          3           0.180838  alfa-romero       gas        std
# 2           2          1           0.180838  alfa-romero       gas        std
# 3           3          2           0.518325         audi       gas        std
# 4           4          2           0.518325         audi       gas        std
# 5           5          2           0.180838         audi       gas        std
# 6           6          1           0.486911         audi       gas        std
# 7           7          1           0.180838         audi       gas        std
# 8           8          1           0.486911         audi       gas      turbo
# 9          10          2           0.664921          bmw       gas        std
#
#   num-of-doors   body-style drive-wheels engine-location  ...  engine-size  \
# 0          two  convertible          rwd           front  ...          130
# 1          two  convertible          rwd           front  ...          130
# 2          two    hatchback          rwd           front  ...          152
# 3         four        sedan          fwd           front  ...          109
# 4         four        sedan          4wd           front  ...          136
# 5          two        sedan          fwd           front  ...          136
# 6         four        sedan          fwd           front  ...          136
# 7         four        wagon          fwd           front  ...          136
# 8         four        sedan          fwd           front  ...          131
# 9          two        sedan          rwd           front  ...          108
#
#    fuel-system  bore  stroke  compression-ratio horsepower peak-rpm  city-mpg  \
# 0         mpfi  3.47    2.68                9.0        111     5000        21
# 1         mpfi  3.47    2.68                9.0        111     5000        21
# 2         mpfi  2.68    3.47                9.0        154     5000        19
# 3         mpfi  3.19    3.40               10.0        102     5500        24
# 4         mpfi  3.19    3.40                8.0        115     5500        18
# 5         mpfi  3.19    3.40                8.5        110     5500        19
# 6         mpfi  3.19    3.40                8.5        110     5500        19
# 7         mpfi  3.19    3.40                8.5        110     5500        19
# 8         mpfi  3.13    3.40                8.3        140     5500        17
# 9         mpfi  3.50    2.80                8.8        101     5800        23
#
#   highway-mpg     price
# 0          27  0.297247
# 1          27  0.363436
# 2          26  0.363436
# 3          30  0.307269
# 4          22  0.384361
# 5          25  0.335903
# 6          25  0.390088
# 7          25  0.416740
# 8          20  0.525881
# 9          29  0.361894
#
# [10 rows x 27 columns]

# %% [markdown]
# ### After Normalizing the normalized-losses

# %%
sb.distplot(df[['normalized-losses']],hist=True)

# %%
#drop unecessary column

df.drop(0)
# Out:
#      Unnamed: 0  symboling  normalized-losses         make fuel-type  \
# 1             1          3           0.180838  alfa-romero       gas
# 2             2          1           0.180838  alfa-romero       gas
# 3             3          2           0.518325         audi       gas
# 4             4          2           0.518325         audi       gas
# 5             5          2           0.180838         audi       gas
# ..          ...        ...                ...          ...       ...
# 196         200         -1           0.157068        volvo       gas
# 197         201         -1           0.157068        volvo       gas
# 198         202         -1           0.157068        volvo       gas
# 199         203         -1           0.157068        volvo    diesel
# 200         204         -1           0.157068        volvo       gas
#
#     aspiration num-of-doors   body-style drive-wheels engine-location  ...  \
# 1          std          two  convertible          rwd           front  ...
# 2          std          two    hatchback          rwd           front  ...
# 3          std         four        sedan          fwd           front  ...
# 4          std         four        sedan          4wd           front  ...
# 5          std          two        sedan          fwd           front  ...
# ..         ...          ...          ...          ...             ...  ...
# 196        std         four        sedan          rwd           front  ...
# 197      turbo         four        sedan          rwd           front  ...
# 198        std         four        sedan          rwd           front  ...
# 199      turbo         four        sedan          rwd           front  ...
# 200      turbo         four        sedan          rwd           front  ...
#
#      engine-size  fuel-system  bore  stroke  compression-ratio horsepower  \
# 1            130         mpfi  3.47    2.68                9.0        111
# 2            152         mpfi  2.68    3.47                9.0        154
# 3            109         mpfi  3.19    3.40               10.0        102
# 4            136         mpfi  3.19    3.40                8.0        115
# 5            136         mpfi  3.19    3.40                8.5        110
# ..           ...          ...   ...     ...                ...        ...
# 196          141         mpfi  3.78    3.15                9.5        114
# 197          141         mpfi  3.78    3.15                8.7        160
# 198          173         mpfi  3.58    2.87                8.8        134
# 199          145          idi  3.01    3.40               23.0        106
# 200          141         mpfi  3.78    3.15                9.5        114
#
#     peak-rpm  city-mpg highway-mpg     price
# 1       5000        21          27  0.363436
# 2       5000        19          26  0.363436
# 3       5500        24          30  0.307269
# 4       5500        18          22  0.384361
# 5       5500        19          25  0.335903
# ..       ...       ...         ...       ...
# 196     5400        23          28  0.371035
# 197     5300        19          25  0.419493
# 198     5500        18          23  0.473238
# 199     4800        26          27  0.494934
# 200     5400        19          25  0.498348
#
# [200 rows x 27 columns]
