# %% [markdown]
# # Cross Validation of Model
#
# #### in-sample training is using the data to test how accurate our model is however we do not know how does it fit with the real world data
# #### Measuring Generaliztion performance involves testing the model with the data that has not been used to train it

# %% [markdown]
# ### Importing the required dependencies

# %%
import pandas as pd
import numpy as np
from sklearn.model_selection import train_test_split

# %%
df = pd.read_csv("../automobiles_fuel_dummies.csv")

# %%
df.head(10)
# Out:
#    Unnamed: 0  symboling  normalized-losses         make fuel-type aspiration  \
# 0           0          3              99.54  alfa-romero       gas        std
# 1           1          3              99.54  alfa-romero       gas        std
# 2           2          1              99.54  alfa-romero       gas        std
# 3           3          2             164.00         audi       gas        std
# 4           4          2             164.00         audi       gas        std
# 5           5          2              99.54         audi       gas        std
# 6           6          1             158.00         audi       gas        std
# 7           7          1              99.54         audi       gas        std
# 8           8          1             158.00         audi       gas      turbo
# 9           9          2             192.00          bmw       gas        std
#
#   num-of-doors   body-style drive-wheels engine-location  ...  stroke  \
# ...

# %% [markdown]
# ### Splitting data into train and test subsets

# %%
x_data = df[['highway-mpg']]
y_data = df[['price']]

x_train,x_test,y_train,y_test = train_test_split(x_data, y_data, test_size = 0.3, random_state = 0)

# %% [markdown]
# ### Cross validation

# %% [markdown]
# #### Randomly shuffling the test and train data set from the given sample and calculating the generalizing error

# %%
from sklearn.model_selection import cross_val_score
from sklearn.linear_model import LinearRegression

# %%
lr = LinearRegression()

# %%
scores = cross_val_score(lr,x_data,y_data,cv=3)

# %%
scores
# Out:
# array([ 0.49385231,  0.48773429, -0.07953989])

# %% [markdown]
# ### The above array are the R squared values as a result of testing and training with 3 sets of random test and train data

# %% [markdown]
# #### Following function shows the predicted values too

# %%
from sklearn.model_selection import cross_val_predict

# %%
values = cross_val_predict(lr,x_data,y_data,cv=3)

# %%
values
# Out:
# array([[15669.43981517],
#        [15669.43981517],
#        [16473.75710818],
#        [13256.48793613],
#        [19691.02628024],
#        [17278.0744012 ],
#        [17278.0744012 ],
#        [17278.0744012 ],
#        [21299.66086627],
#        [14060.80522914],
#        [14060.80522914],
#        [14865.12252216],
#        [14865.12252216],
#        [17278.0744012 ],
#        [19691.02628024],
#        [19691.02628024],
#        [21299.66086627],
#        [-5242.8098032 ],
#        [ 2800.36312694],
#        [ 2800.36312694],
#        [ 4408.99771297],
#        [ 6821.94959201],
#        [13256.48793613],
#        [ 6821.94959201],
#        [ 6821.94959201],
#        [ 6821.94959201],
#        [13256.48793613],
#        [13256.48793613],
#        [18082.39169421],
#        [-6047.12709621],
#        [ 6821.94959201],
#        [ 3604.68041996],
#        [10039.21876407],
#        [10039.21876407],
#        [10039.21876407],
#        [10039.21876407],
#        [10843.53605709],
# ...
