# %%
import pandas as pd
# %matplotlib notebook
import matplotlib.pyplot as plt

# %%
data = {'id':[1,2,3,4],'name':['a','b','c','d'],'age':[22,45,33,16],'salary':[22000,45000,34000,12000]}

# %%
df = pd.DataFrame(data, columns = ('id','name','age','salary'))

# %%
df
# Out:
#    id name  age  salary
# 0   1    a   22   22000
# 1   2    b   45   45000
# 2   3    c   33   34000
# 3   4    d   16   12000

# %%
df['salary'].plot(kind='bar')
# Out:
# <img src="data:image/png;base64,..." width="640">

# %%
plt.plot(5,5,'o')
# Out:
# <img src="data:image/png;base64,..." width="640">
