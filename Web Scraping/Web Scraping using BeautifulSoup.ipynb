# %%
import requests
from bs4 import BeautifulSoup

# %%
url = 'https://www.ucc.ie/en/'
response=requests.get(url)
soup=BeautifulSoup(response.text,'html.parser')

# %%
for link in soup.find_all('a'):
    print(link.get('href'))
# Out:
# None
# https://www.ucc.ie/cookies
# javascript:;
# /en/
# /en/
# /ga/
# https://www.ucc.ie/en/emt/covid19/
# /en/study/courses/
# #
# /
# javascript:;
# javascript:;
# https://www.ucc.ie/en/contact/
# http://booleweb.ucc.ie/
# https://www.ucc.ie/en/staff/
# https://www.ucc.ie/en/students/
# /en/exams/
# https://canvas.ucc.ie
# https://umail.ucc.ie
# https://visit.ucc.ie
# http://mytimetable.ucc.ie/
# https://app.ucc.ie/maps/
# https://www.ucc.ie/en/students/wellbeing/
# https://www.ucc.ie/en/hr/vacancies/
# https://www.ucc.ie/calendar/
# #
# /en/study/
# /en/study/courses/
# /en/study/undergrad/
# /en/study/postgrad/
# /en/international/
# /en/ace/
# /en/online/
# /en/cpd/
# /en/scholarships/
# /en/study/transition-in/
# /en/graduateattributes/
# /en/ask/
# /en/study/undergrad/firstyear/
# /en/collaborative/
# /en/research/
# /en/research/about/
# /en/research/themes/
# /en/research/support/
# http://research.ucc.ie/profiles/
# /en/research/innovationandtechnologytransfer/
# /en/research/researchviewnewsletter/
# /en/discover/
# /en/discover/history/
# /en/news/
# /en/discover/leadership/
# /en/discover/campus/
# /en/discover/visit/
# /en/awards/
# /en/discover/cork/
# /en/civic/covid19/
# /en/schoolsdepartments/
# /en/schoolsdepartments/academicschoolsanddepartments/
# /en/schoolsdepartments/admin/
# /en/bus-ent/
# https://www.ucc.ie/en/careers/areyouanemployer/employers/
# https://www.ucc.ie/en/careers/areyouanemployer/employers/recruiting/
# https://www.cubsucc.com/executive-education/
# /en/cpd/
# /en/research/
# /en/entrepreneurship/
# /en/alumni/
# http://alumni.ucc.ie/s/1901/bp19/interior.aspx?sid=1901&gid=2&pgid=484
# http://alumni.ucc.ie/s/1901/bp19/interior.aspx?sid=1901&gid=2&pgid=485
# http://alumni.ucc.ie/s/1901/bp19/interior.aspx?sid=1901&gid=2&pgid=486
# http://alumni.ucc.ie/s/1901/bp19/interior.aspx?sid=1901&gid=2&pgid=475
# https://securealumni.ucc.ie/s/1901/bp19/interior.aspx?sid=1901&gid=2&pgid=552&cid=1420
# http://alumni.ucc.ie/s/1901/bp19/interior.aspx?sid=1901&gid=2&pgid=477
# /
# javascript:;
# javascript:;
# #website-quick
# #people-quick
# #courses-quick
# #
# #
# /
# javascript:;
# javascript:;
# /en/emt/covid19/timetables/
# /en/emt/covid19/timetables/
# /en/emt/covid19/
# /en/emt/covid19/charter/
# javascript:;
# /en/study/courses/
# /en/research/
# /en/discover/
# /en/bus-ent/
# http://alumni.ucc.ie/s/1901/bp19/home.aspx?sid=1901&gid=2
# https://events.ucc.ie
# /en/news/virtual-history-conference-to-mark-the-centenary-of-the-terence-macswiney-and-the-cork-mens-gaol-hunger-strike.html
# /en/news/ucc-awarded-significant-hci-3-funding.html
# /en/news/taoiseach-visits-uccs-tyndall-national-institute-.html
# /en/news/ucc-nursing--midwifery-and-dental-schools-awarded-for-equality-work.html
# /en/news/important-new-academic-term-update-.html
# /en/news/
# https://twitter.com/UCC/status/1240754789916565504?s=20
# /en/emt/covid19/charter/
# https://twitter.com/UCC/status/1309391185098747904
# https://www.facebook.com/universitycollegecork/posts/2810571482325339
# https://www.instagram.com/p/CFj6mx2pDCj/
# https://twitter.com/UCC/status/1240595471753793537
# http://uccshop.ie/
# /en/awards/
# http://www.corkuniversitypress.com/
# https://www.ucc.ie/en/contact/
# http://collegeroad.ie
# tel:+353 (0)21 490 3000
# https://www.google.ie/maps/place/University+College+Cork/@51.8889472,-8.474624,14z/data=!4m5!3m4!1s0x4844902380bbc323:0x4d8a4bf0835e5291!8m2!3d51.8921099!4d-8.4932739
# https://twitter.com/ucc
# https://www.facebook.com/universitycollegecork
# https://www.instagram.com/universitycollegecork/
# https://www.youtube.com/user/UCCIreland
# https://www.linkedin.com/school/university-college-cork-ireland-ucc-/
# #footer1
# tel:+353214903000
# https://www.google.ie/maps/place/University+College+Cork/@51.8889472,-8.474624,14z/data=!4m5!3m4!1s0x4844902380bbc323:0x4d8a4bf0835e5291!8m2!3d51.8921099!4d-8.4932739
# #footer2
# #
# /en/study/
# #
# /en/research/
# /en/discover/
# /en/schoolsdepartments/
# /en/bus-ent/
# http://alumni.ucc.ie/s/1901/bp19/home.aspx?sid=1901&gid=2
# #footer3
# /en/contact/
# http://libguides.ucc.ie/library
# /en/staff/
# /en/exams/
# /en/build/roombookings/timetables/
# https://canvas.ucc.ie
# /en/discover/visit/maps/
# #footer4
# https://www.ucc.ie/en/sitemap/
# /en/legal/
# mailto:abuse@ucc.ie?subject=Abuse%20Report%20from%20UCC%20Webpage&body=http://www.ucc.ie/en/
# https://www.ucc.ie/privacy
# https://www.ucc.ie/en/it-policies/policies/cookies/
# https://www.ucc.ie/aup
# mailto:webmaster@ucc.ie?Subject=Web%20site%20query
# https://www.ucc.ie/en/athenaswan/
# https://www.ucc.ie/en/hr/research//uccresearcherstrategy/
# https://www.wearecork.ie/
# https://stars.aashe.org/institutions/university-college-cork-national-university-of-ireland-cork-co-corcaigh/report/2018-07-20/
# #
